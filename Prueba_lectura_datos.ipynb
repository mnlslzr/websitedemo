# %% [markdown]
# <a href="https://colab.research.google.com/github/mnlslzr/websitedemo/blob/master/Prueba_lectura_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wfdb scipy numpy tensorflow scikit-learn matplotlib

import numpy as np
import wfdb
from scipy.signal import resample, butter, filtfilt, iirnotch
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Input, UpSampling1D
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report


# --- Funciones de preprocesamiento ---
def filtro_pasa_banda(senal, fs, lowcut=0.5, highcut=40.0, orden=4):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(orden, [low, high], btype='band')
    return filtfilt(b, a, senal)

def filtro_notch(senal, fs, freq_notch=60.0, Q=30.0):
    w0 = freq_notch / (fs / 2)
    b, a = iirnotch(w0, Q)
    return filtfilt(b, a, senal)

def normalizar_segmento(segmento):
    min_val = np.min(segmento)
    max_val = np.max(segmento)
    if max_val == min_val:
        return segmento - min_val
    return (segmento - min_val) / (max_val - min_val)

def ajustar_frecuencia(senal, frecuencia_original, frecuencia_deseada=360):
    if frecuencia_original == frecuencia_deseada:
        return senal
    num_muestras_nuevo = int(len(senal) * frecuencia_deseada / frecuencia_original)
    return resample(senal, num_muestras_nuevo)

def segmentar_y_normalizar(senal, picos, tamano_ventana=256): # Adjusted window size to be a power of 2
    segmentos = []
    indices_validos = []
    for i, pico in enumerate(picos):
        inicio = pico - tamano_ventana // 2
        fin = pico + tamano_ventana // 2
        if inicio >= 0 and fin <= len(senal):
            segmento = senal[inicio:fin]
            if len(segmento) == tamano_ventana:
                segmento_norm = normalizar_segmento(segmento)
                segmentos.append(segmento_norm)
                indices_validos.append(i)
    return np.array(segmentos), indices_validos

# --- Cargar y procesar MIT-BIH ---
registros = [str(i) for i in range(100, 235)]
segmentos_total = []
etiquetas_total = []
frecuencia_mit = 360

for reg in registros:
    try:
        print(f"Procesando registro {reg}...")
        record_mit = wfdb.rdrecord(reg, pn_dir='mitdb/')
        annotation_mit = wfdb.rdann(reg, extension='atr', pn_dir='mitdb/')
        senal_mit = record_mit.p_signal[:, 0]
        picos_mit = annotation_mit.sample
        etiquetas_mit = annotation_mit.symbol

        senal_mit_ajustada = ajustar_frecuencia(senal_mit, frecuencia_mit)
        senal_mit_filtrada = filtro_pasa_banda(senal_mit_ajustada, fs=frecuencia_mit)
        senal_mit_filtrada = filtro_notch(senal_mit_filtrada, fs=frecuencia_mit)

        segmentos_reg, indices_validos = segmentar_y_normalizar(senal_mit_filtrada, picos_mit)
        etiquetas_reg = [etiquetas_mit[i] for i in indices_validos]

        segmentos_total.extend(segmentos_reg)
        etiquetas_total.extend(etiquetas_reg)
    except Exception as e:
        print(f"Error al procesar registro {reg}: {str(e)}")
        continue

segmentos_total = np.array(segmentos_total)
etiquetas_total = np.array(etiquetas_total)
print(f"Total de segmentos procesados: {len(segmentos_total)}")

# --- Agrupar etiquetas AAMI ---
mapeo_aami = {'N': 'N', 'L': 'N', 'R': 'N', 'A': 'S', 'S': 'S', 'J': 'S', 'V': 'V', 'E': 'V', 'F': 'F', 'Q': 'Q', 'f': 'Q', '/': 'Q', '+': 'Q'}
etiquetas_aami = [mapeo_aami.get(e, 'Q') for e in etiquetas_total]
from collections import Counter
print("Distribución de clases AAMI:", Counter(etiquetas_aami))

# Convertir a one-hot y obtener etiquetas numéricas
codificador = LabelEncoder()
etiquetas_numeros = codificador.fit_transform(etiquetas_aami)
etiquetas_onehot = to_categorical(etiquetas_numeros)

# --- Calcular pesos de clases ---
pesos = class_weight.compute_class_weight('balanced', classes=np.unique(etiquetas_numeros), y=etiquetas_numeros)
pesos_dict = dict(enumerate(pesos))
print("Pesos de clases:", pesos_dict)

# --- Autoencoder convolucional ---
input_shape = (256, 1) # Adjusted input shape
input_signal = Input(shape=input_shape)

# Encoder
x = Conv1D(32, kernel_size=5, activation='relu', padding='same')(input_signal)
x = MaxPooling1D(pool_size=2)(x)
x = Conv1D(16, kernel_size=5, activation='relu', padding='same')(x)
encoded = MaxPooling1D(pool_size=2)(x) # Output shape will be (64, 16)

# Decoder
x = Conv1D(16, kernel_size=5, activation='relu', padding='same')(encoded)
x = UpSampling1D(size=2)(x)
x = Conv1D(32, kernel_size=5, activation='relu', padding='same')(x)
x = UpSampling1D(size=2)(x) # Output shape will be (256, 32)
decoded = Conv1D(1, kernel_size=3, activation='linear', padding='same')(x)

autoencoder = Model(input_signal, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

encoder = Model(input_signal, encoded)

# Entrenar autoencoder
X_auto = segmentos_total[..., np.newaxis]
X_train_auto, X_val_auto = train_test_split(X_auto, test_size=0.2, random_state=42)
autoencoder.fit(X_train_auto, X_train_auto, epochs=20, batch_size=32, validation_data=(X_val_auto, X_val_auto))

# Extraer representaciones latentes
encoded_segments = encoder.predict(X_auto)
print("Forma de las representaciones latentes:", encoded_segments.shape)

# --- Modelo híbrido CNN-LSTM ---
modelo_hibrido = Sequential([
    Conv1D(32, kernel_size=5, activation='relu', input_shape=(encoded_segments.shape[1], encoded_segments.shape[2])), # Adjusted input shape
    MaxPooling1D(pool_size=2),
    Conv1D(64, kernel_size=5, activation='relu'),
    MaxPooling1D(pool_size=2),
    LSTM(128, return_sequences=False),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(5, activation='softmax')
])
modelo_hibrido.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenar modelo híbrido con pesos de clase
X_train, X_test, y_train, y_test = train_test_split(encoded_segments, etiquetas_onehot, test_size=0.2, random_state=42)
historia = modelo_hibrido.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, class_weight=pesos_dict)

# --- Evaluar ---
perdida, precision = modelo_hibrido.evaluate(X_test, y_test)
print(f"Precisión en prueba: {precision * 100:.2f}%")

# --- Generar gráficas de pérdida y precisión ---
#plt.style.use('seaborn')  # Estilo más limpio

# Gráfica de pérdida
plt.figure(figsize=(10, 5))
plt.plot(historia.history['loss'], label='Pérdida (Entrenamiento)', color='blue', linewidth=2)
plt.plot(historia.history['val_loss'], label='Pérdida (Validación)', color='orange', linestyle='--', linewidth=2)
plt.title('Pérdida durante el entrenamiento', fontsize=14)
plt.xlabel('Época', fontsize=12)
plt.ylabel('Pérdida (Categorical Crossentropy)', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/perdida.png')  # Guardar en Colab
plt.show()

# Gráfica de precisión
plt.figure(figsize=(10, 5))
plt.plot(historia.history['accuracy'], label='Precisión (Entrenamiento)', color='blue', linewidth=2)
plt.plot(historia.history['val_accuracy'], label='Precisión (Validación)', color='orange', linestyle='--', linewidth=2)
plt.title('Precisión durante el entrenamiento', fontsize=14)
plt.xlabel('Época', fontsize=12)
plt.ylabel('Precisión', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/precision.png')  # Guardar en Colab
plt.show()

# --- Evaluación detallada por clase ---
y_pred = modelo_hibrido.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)
print("\nReporte de clasificación:")
print(classification_report(y_test_classes, y_pred_classes, target_names=codificador.classes_))
# Out:
# Requirement already satisfied: wfdb in /usr/local/lib/python3.12/dist-packages (4.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.12.15)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2025.3.0)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.3.2)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.32.4)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.20.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2025.8.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Procesando registro 100...
# Procesando registro 101...
# Procesando registro 102...
# Procesando registro 103...
# Procesando registro 104...
# Procesando registro 105...
# Procesando registro 106...
# Procesando registro 107...
# Procesando registro 108...
# Procesando registro 109...
# Procesando registro 110...
# Error al procesar registro 110: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/110.hea
# Procesando registro 111...
# Procesando registro 112...
# Procesando registro 113...
# Procesando registro 114...
# Procesando registro 115...
# Procesando registro 116...
# Procesando registro 117...
# Procesando registro 118...
# Procesando registro 119...
# Procesando registro 120...
# Error al procesar registro 120: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/120.hea
# Procesando registro 121...
# Procesando registro 122...
# Procesando registro 123...
# Procesando registro 124...
# Procesando registro 125...
# Error al procesar registro 125: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/125.hea
# Procesando registro 126...
# Error al procesar registro 126: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/126.hea
# Procesando registro 127...
# Error al procesar registro 127: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/127.hea
# Procesando registro 128...
# Error al procesar registro 128: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/128.hea
# Procesando registro 129...
# Error al procesar registro 129: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/129.hea
# Procesando registro 130...
# Error al procesar registro 130: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/130.hea
# Procesando registro 131...
# Error al procesar registro 131: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/131.hea
# Procesando registro 132...
# Error al procesar registro 132: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/132.hea
# Procesando registro 133...
# Error al procesar registro 133: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/133.hea
# Procesando registro 134...
# Error al procesar registro 134: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/134.hea
# Procesando registro 135...
# Error al procesar registro 135: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/135.hea
# Procesando registro 136...
# Error al procesar registro 136: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/136.hea
# Procesando registro 137...
# Error al procesar registro 137: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/137.hea
# Procesando registro 138...
# Error al procesar registro 138: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/138.hea
# Procesando registro 139...
# Error al procesar registro 139: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/139.hea
# Procesando registro 140...
# Error al procesar registro 140: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/140.hea
# Procesando registro 141...
# Error al procesar registro 141: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/141.hea
# Procesando registro 142...
# Error al procesar registro 142: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/142.hea
# Procesando registro 143...
# Error al procesar registro 143: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/143.hea
# Procesando registro 144...
# Error al procesar registro 144: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/144.hea
# Procesando registro 145...
# Error al procesar registro 145: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/145.hea
# Procesando registro 146...
# Error al procesar registro 146: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/146.hea
# Procesando registro 147...
# Error al procesar registro 147: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/147.hea
# Procesando registro 148...
# Error al procesar registro 148: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/148.hea
# Procesando registro 149...
# Error al procesar registro 149: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/149.hea
# Procesando registro 150...
# Error al procesar registro 150: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/150.hea
# Procesando registro 151...
# Error al procesar registro 151: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/151.hea
# Procesando registro 152...
# Error al procesar registro 152: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/152.hea
# Procesando registro 153...
# Error al procesar registro 153: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/153.hea
# Procesando registro 154...
# Error al procesar registro 154: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/154.hea
# Procesando registro 155...
# Error al procesar registro 155: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/155.hea
# Procesando registro 156...
# Error al procesar registro 156: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/156.hea
# Procesando registro 157...
# Error al procesar registro 157: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/157.hea
# Procesando registro 158...
# Error al procesar registro 158: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/158.hea
# Procesando registro 159...
# Error al procesar registro 159: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/159.hea
# Procesando registro 160...
# Error al procesar registro 160: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/160.hea
# Procesando registro 161...
# Error al procesar registro 161: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/161.hea
# Procesando registro 162...
# Error al procesar registro 162: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/162.hea
# Procesando registro 163...
# Error al procesar registro 163: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/163.hea
# Procesando registro 164...
# Error al procesar registro 164: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/164.hea
# Procesando registro 165...
# Error al procesar registro 165: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/165.hea
# Procesando registro 166...
# Error al procesar registro 166: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/166.hea
# Procesando registro 167...
# Error al procesar registro 167: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/167.hea
# Procesando registro 168...
# Error al procesar registro 168: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/168.hea
# Procesando registro 169...
# Error al procesar registro 169: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/169.hea
# Procesando registro 170...
# Error al procesar registro 170: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/170.hea
# Procesando registro 171...
# Error al procesar registro 171: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/171.hea
# Procesando registro 172...
# Error al procesar registro 172: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/172.hea
# Procesando registro 173...
# Error al procesar registro 173: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/173.hea
# Procesando registro 174...
# Error al procesar registro 174: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/174.hea
# Procesando registro 175...
# Error al procesar registro 175: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/175.hea
# Procesando registro 176...
# Error al procesar registro 176: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/176.hea
# Procesando registro 177...
# Error al procesar registro 177: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/177.hea
# Procesando registro 178...
# Error al procesar registro 178: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/178.hea
# Procesando registro 179...
# Error al procesar registro 179: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/179.hea
# Procesando registro 180...
# Error al procesar registro 180: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/180.hea
# Procesando registro 181...
# Error al procesar registro 181: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/181.hea
# Procesando registro 182...
# Error al procesar registro 182: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/182.hea
# Procesando registro 183...
# Error al procesar registro 183: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/183.hea
# Procesando registro 184...
# Error al procesar registro 184: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/184.hea
# Procesando registro 185...
# Error al procesar registro 185: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/185.hea
# Procesando registro 186...
# Error al procesar registro 186: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/186.hea
# Procesando registro 187...
# Error al procesar registro 187: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/187.hea
# Procesando registro 188...
# Error al procesar registro 188: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/188.hea
# Procesando registro 189...
# Error al procesar registro 189: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/189.hea
# Procesando registro 190...
# Error al procesar registro 190: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/190.hea
# Procesando registro 191...
# Error al procesar registro 191: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/191.hea
# Procesando registro 192...
# Error al procesar registro 192: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/192.hea
# Procesando registro 193...
# Error al procesar registro 193: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/193.hea
# Procesando registro 194...
# Error al procesar registro 194: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/194.hea
# Procesando registro 195...
# Error al procesar registro 195: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/195.hea
# Procesando registro 196...
# Error al procesar registro 196: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/196.hea
# Procesando registro 197...
# Error al procesar registro 197: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/197.hea
# Procesando registro 198...
# Error al procesar registro 198: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/198.hea
# Procesando registro 199...
# Error al procesar registro 199: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/199.hea
# Procesando registro 200...
# Procesando registro 201...
# Procesando registro 202...
# Procesando registro 203...
# Procesando registro 204...
# Error al procesar registro 204: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/204.hea
# Procesando registro 205...
# Procesando registro 206...
# Error al procesar registro 206: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/206.hea
# Procesando registro 207...
# Procesando registro 208...
# Procesando registro 209...
# Procesando registro 210...
# Procesando registro 211...
# Error al procesar registro 211: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/211.hea
# Procesando registro 212...
# Procesando registro 213...
# Procesando registro 214...
# Procesando registro 215...
# Procesando registro 216...
# Error al procesar registro 216: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/216.hea
# Procesando registro 217...
# Procesando registro 218...
# Error al procesar registro 218: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/218.hea
# Procesando registro 219...
# Procesando registro 220...
# Procesando registro 221...
# Procesando registro 222...
# Procesando registro 223...
# Procesando registro 224...
# Error al procesar registro 224: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/224.hea
# Procesando registro 225...
# Error al procesar registro 225: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/225.hea
# Procesando registro 226...
# Error al procesar registro 226: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/226.hea
# Procesando registro 227...
# Error al procesar registro 227: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/227.hea
# Procesando registro 228...
# Procesando registro 229...
# Error al procesar registro 229: 404 Error: Not Found for url: https://physionet.org/files/mitdb/1.0.0/229.hea
# Procesando registro 230...
# Procesando registro 231...
# Procesando registro 232...
# Procesando registro 233...
# Procesando registro 234...
# Total de segmentos procesados: 112558
# Distribución de clases AAMI: Counter({'N': 90348, 'Q': 11542, 'V': 7235, 'S': 2631, 'F': 802})
# Pesos de clases: {0: np.float64(28.06932668329177), 1: np.float64(0.24916544915216718), 2: np.float64(1.9504072084560735), 3: np.float64(8.556290383884454), 4: np.float64(3.1114858327574293)}
# Epoch 1/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 65s 23ms/step - loss: 0.0014 - val_loss: 9.1421e-06
# Epoch 2/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 1.2372e-05 - val_loss: 3.3436e-06
# Epoch 3/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 79s 20ms/step - loss: 1.5473e-05 - val_loss: 2.0855e-06
# Epoch 4/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 83s 20ms/step - loss: 6.9227e-06 - val_loss: 1.4953e-06
# Epoch 5/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 83s 21ms/step - loss: 3.7328e-06 - val_loss: 4.6256e-06
# Epoch 6/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 83s 21ms/step - loss: 3.8831e-06 - val_loss: 1.1094e-06
# Epoch 7/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 3.6254e-06 - val_loss: 1.1818e-06
# Epoch 8/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 83s 21ms/step - loss: 5.1274e-06 - val_loss: 9.5881e-07
# Epoch 9/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 58s 21ms/step - loss: 2.2284e-06 - val_loss: 1.9271e-06
# Epoch 10/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 57s 20ms/step - loss: 3.6465e-06 - val_loss: 1.7759e-06
# Epoch 11/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 82s 20ms/step - loss: 3.0815e-06 - val_loss: 7.0178e-07
# Epoch 12/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 58s 21ms/step - loss: 2.4828e-06 - val_loss: 2.1060e-06
# Epoch 13/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 57s 20ms/step - loss: 2.6347e-06 - val_loss: 1.4048e-06
# Epoch 14/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 82s 20ms/step - loss: 1.5111e-06 - val_loss: 4.3982e-07
# Epoch 15/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 57s 20ms/step - loss: 1.3874e-06 - val_loss: 4.8949e-07
# Epoch 16/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 57s 20ms/step - loss: 1.4845e-06 - val_loss: 7.9430e-07
# Epoch 17/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 57s 20ms/step - loss: 2.4963e-06 - val_loss: 1.0230e-06
# Epoch 18/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 59s 21ms/step - loss: 1.4662e-06 - val_loss: 3.7866e-07
# Epoch 19/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 79s 20ms/step - loss: 2.7088e-06 - val_loss: 6.3694e-07
# Epoch 20/20
# 2814/2814 ━━━━━━━━━━━━━━━━━━━━ 85s 21ms/step - loss: 1.2349e-06 - val_loss: 4.3083e-07
# 3518/3518 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step
# Forma de las representaciones latentes: (112558, 64, 16)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 67s 28ms/step - accuracy: 0.4428 - loss: 1.1039 - val_accuracy: 0.6380 - val_loss: 0.8493
# Epoch 2/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 84s 29ms/step - accuracy: 0.7006 - loss: 0.5667 - val_accuracy: 0.7235 - val_loss: 0.7793
# Epoch 3/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 64s 28ms/step - accuracy: 0.7831 - loss: 0.4225 - val_accuracy: 0.7711 - val_loss: 0.5827
# Epoch 4/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 63s 28ms/step - accuracy: 0.8484 - loss: 0.3349 - val_accuracy: 0.8546 - val_loss: 0.4641
# Epoch 5/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 84s 29ms/step - accuracy: 0.8931 - loss: 0.2764 - val_accuracy: 0.8717 - val_loss: 0.3795
# Epoch 6/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 64s 28ms/step - accuracy: 0.8979 - loss: 0.2540 - val_accuracy: 0.9320 - val_loss: 0.2727
# Epoch 7/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 87s 30ms/step - accuracy: 0.9139 - loss: 0.2101 - val_accuracy: 0.9590 - val_loss: 0.1360
# Epoch 8/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 77s 28ms/step - accuracy: 0.9239 - loss: 0.1889 - val_accuracy: 0.9328 - val_loss: 0.2129
# Epoch 9/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 82s 28ms/step - accuracy: 0.9297 - loss: 0.1593 - val_accuracy: 0.9012 - val_loss: 0.2681
# Epoch 10/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 70s 31ms/step - accuracy: 0.9395 - loss: 0.1384 - val_accuracy: 0.9448 - val_loss: 0.1729
# Epoch 11/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 64s 28ms/step - accuracy: 0.9379 - loss: 0.1408 - val_accuracy: 0.9505 - val_loss: 0.1571
# Epoch 12/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 64s 29ms/step - accuracy: 0.9446 - loss: 0.1306 - val_accuracy: 0.9621 - val_loss: 0.1289
# Epoch 13/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 67s 30ms/step - accuracy: 0.9526 - loss: 0.1142 - val_accuracy: 0.9517 - val_loss: 0.1566
# Epoch 14/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 80s 29ms/step - accuracy: 0.9578 - loss: 0.0935 - val_accuracy: 0.9573 - val_loss: 0.1366
# Epoch 15/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 83s 29ms/step - accuracy: 0.9503 - loss: 0.1111 - val_accuracy: 0.9653 - val_loss: 0.1089
# Epoch 16/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 80s 29ms/step - accuracy: 0.9478 - loss: 0.0967 - val_accuracy: 0.9729 - val_loss: 0.0902
# Epoch 17/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 86s 30ms/step - accuracy: 0.9577 - loss: 0.0882 - val_accuracy: 0.9614 - val_loss: 0.1195
# Epoch 18/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 78s 29ms/step - accuracy: 0.9569 - loss: 0.0850 - val_accuracy: 0.9446 - val_loss: 0.1521
# Epoch 19/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 81s 28ms/step - accuracy: 0.9568 - loss: 0.0944 - val_accuracy: 0.9575 - val_loss: 0.1298
# Epoch 20/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 65s 29ms/step - accuracy: 0.9514 - loss: 0.0818 - val_accuracy: 0.9754 - val_loss: 0.0869
# Epoch 21/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 83s 29ms/step - accuracy: 0.9693 - loss: 0.0633 - val_accuracy: 0.9288 - val_loss: 0.1716
# Epoch 22/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 88s 32ms/step - accuracy: 0.9616 - loss: 0.0719 - val_accuracy: 0.9670 - val_loss: 0.1049
# Epoch 23/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 79s 30ms/step - accuracy: 0.9653 - loss: 0.0663 - val_accuracy: 0.9707 - val_loss: 0.1010
# Epoch 24/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 79s 29ms/step - accuracy: 0.9676 - loss: 0.0653 - val_accuracy: 0.9517 - val_loss: 0.1689
# Epoch 25/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 65s 29ms/step - accuracy: 0.9672 - loss: 0.0498 - val_accuracy: 0.9532 - val_loss: 0.1341
# Epoch 26/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 65s 29ms/step - accuracy: 0.9693 - loss: 0.0483 - val_accuracy: 0.9685 - val_loss: 0.1006
# Epoch 27/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 65s 29ms/step - accuracy: 0.9659 - loss: 0.0701 - val_accuracy: 0.9579 - val_loss: 0.1225
# Epoch 28/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 85s 31ms/step - accuracy: 0.9593 - loss: 0.0642 - val_accuracy: 0.9774 - val_loss: 0.0804
# Epoch 29/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 78s 29ms/step - accuracy: 0.9682 - loss: 0.0568 - val_accuracy: 0.9789 - val_loss: 0.0762
# Epoch 30/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 66s 29ms/step - accuracy: 0.9722 - loss: 0.0502 - val_accuracy: 0.9673 - val_loss: 0.1010
# Epoch 31/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 65s 29ms/step - accuracy: 0.9700 - loss: 0.0542 - val_accuracy: 0.9663 - val_loss: 0.1082
# Epoch 32/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 82s 29ms/step - accuracy: 0.9700 - loss: 0.0553 - val_accuracy: 0.9714 - val_loss: 0.1034
# Epoch 33/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 64s 29ms/step - accuracy: 0.9731 - loss: 0.0478 - val_accuracy: 0.9176 - val_loss: 0.2583
# Epoch 34/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 69s 30ms/step - accuracy: 0.9659 - loss: 0.0471 - val_accuracy: 0.9532 - val_loss: 0.1338
# Epoch 35/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 80s 30ms/step - accuracy: 0.9689 - loss: 0.0467 - val_accuracy: 0.9589 - val_loss: 0.1111
# Epoch 36/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 84s 31ms/step - accuracy: 0.9751 - loss: 0.0425 - val_accuracy: 0.9765 - val_loss: 0.0869
# Epoch 37/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 66s 29ms/step - accuracy: 0.9755 - loss: 0.0441 - val_accuracy: 0.9529 - val_loss: 0.1352
# Epoch 38/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 81s 29ms/step - accuracy: 0.9665 - loss: 0.0622 - val_accuracy: 0.9757 - val_loss: 0.0844
# Epoch 39/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 82s 29ms/step - accuracy: 0.9737 - loss: 0.0448 - val_accuracy: 0.9731 - val_loss: 0.0975
# Epoch 40/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 70s 31ms/step - accuracy: 0.9778 - loss: 0.0387 - val_accuracy: 0.9697 - val_loss: 0.1160
# Epoch 41/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 76s 29ms/step - accuracy: 0.9745 - loss: 0.0453 - val_accuracy: 0.9746 - val_loss: 0.0904
# Epoch 42/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 66s 29ms/step - accuracy: 0.9735 - loss: 0.0504 - val_accuracy: 0.9743 - val_loss: 0.0954
# Epoch 43/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 81s 29ms/step - accuracy: 0.9790 - loss: 0.0319 - val_accuracy: 0.9754 - val_loss: 0.0979
# Epoch 44/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 65s 29ms/step - accuracy: 0.9739 - loss: 0.0539 - val_accuracy: 0.9680 - val_loss: 0.1037
# Epoch 45/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 68s 30ms/step - accuracy: 0.9789 - loss: 0.0335 - val_accuracy: 0.9800 - val_loss: 0.0882
# Epoch 46/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 83s 31ms/step - accuracy: 0.9765 - loss: 0.0390 - val_accuracy: 0.9730 - val_loss: 0.0964
# Epoch 47/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 67s 30ms/step - accuracy: 0.9798 - loss: 0.0359 - val_accuracy: 0.9687 - val_loss: 0.1255
# Epoch 48/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 80s 28ms/step - accuracy: 0.9773 - loss: 0.0450 - val_accuracy: 0.9649 - val_loss: 0.1074
# Epoch 49/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 84s 29ms/step - accuracy: 0.9769 - loss: 0.0427 - val_accuracy: 0.9704 - val_loss: 0.1070
# Epoch 50/50
# 2252/2252 ━━━━━━━━━━━━━━━━━━━━ 80s 29ms/step - accuracy: 0.9816 - loss: 0.0333 - val_accuracy: 0.9590 - val_loss: 0.1215
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9589 - loss: 0.1264
# Precisión en prueba: 95.91%
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            F       0.20      0.92      0.33       132
#            N       1.00      0.96      0.98     18041
#            Q       0.98      0.97      0.98      2297
#            S       0.70      0.95      0.81       527
#            V       0.93      0.97      0.95      1515
#
#     accuracy                           0.96     22512
#    macro avg       0.76      0.96      0.81     22512
# weighted avg       0.98      0.96      0.97     22512
